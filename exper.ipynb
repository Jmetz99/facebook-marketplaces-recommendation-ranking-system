# %%
import pandas as pd

df = pd.read_csv('cleaned_products.csv', lineterminator="\n")

df.head(20)
# Out:
#     Unnamed: 0.1  Unnamed: 0                                    id  \
# 0              0           0  243809c0-9cfc-4486-ad12-3b7a16605ba9
# 1              1           1  1c58d3f9-8b93-47ea-9415-204fcc2a22e6
# 2              2           2  860673f1-57f6-47ba-8d2f-13f9e05b8f9a
# 3              3           3  59948726-29be-4b35-ade5-bb2fd7331856
# 4              4           4  16dbc860-696e-4cda-93f6-4dd4926573fb
# 5              5           5  5707be4f-49d9-4feb-b2c8-aa0868405c65
# 6              6           6  d2244a7b-aef4-4495-aff7-0c55bf512d6e
# 7              7           7  485edc04-7bbc-430a-9430-f05a77f5a917
# 8              8           8  7e538445-c75e-4802-8dc5-a9083a802278
# 9              9           9  1a64843d-72f3-4141-946f-fa9b978fe755
# 10            10          10  ac514199-1ceb-4703-902d-4d8c55bea7e4
# 11            11          11  f36672f9-fbe5-40ac-8f5d-015c660c3304
# 12            12          12  5f5f57d7-778f-4336-bb10-b43863418c8c
# ...
